# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Hp\\Desktop\\cifar10-image-classificatio\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Hp\\Desktop\\cifar10-image-classificatio'

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from sklearn.metrics import (
    confusion_matrix,
    classification_report
)

# %%
from pathlib import Path

print(Path("artifacts/training").exists())
print(list(Path("artifacts/training").glob("*")))
# Out:
# False
# []

# %%
model = tf.keras.models.load_model(
    "artifacts/training/model.h5"
)

print("✅ Model Loaded Successfully")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hp\AppData\Local\Temp\ipykernel_19156\3452382266.py", line 1, in <module>
#     model = tf.keras.models.load_model(
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\keras\src\saving\saving_api.py", line 238, in load_model
#     return legacy_sm_saving_lib.load_model(
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\keras\src\saving\legacy\save.py", line 234, in load_model
#     raise IOError(
# OSError: No file or directory found at artifacts/training/model.h5
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\IPython\core\ultratb.py", line 778, in lines
#     return self._sd.lines
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\core.py", line 677, in included_pieces
#     scope_pieces = self.scope_pieces
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\core.py", line 614, in scope_pieces
#     scope_start, scope_end = self.source.line_range(self.scope)
#   File "c:\Users\Hp\anaconda3\envs\abc\lib\site-packages\stack_data\core.py", line 178, in line_range
#     return line_range(self.asttext(), node)
# AttributeError: 'Source' object has no attribute 'asttext'
